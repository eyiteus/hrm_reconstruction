# %%
from google.colab import drive
drive.mount('/content/drive')

base_dir = "/content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM"
# %cd "$base_dir"

# Clean any bad repo (only if needed)
# !rm -rf .git

# Init repo
# !git init

# Set identity
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"

# Ignore Google Drive pointer files
# !echo "*.gdoc" >> .gitignore
# !echo "*.gsheet" >> .gitignore
# !echo "*.gslides" >> .gitignore

# Add remote
# !git remote add origin https://github.com/Eyiteus/HRM_Reconstruction.git

# Commit + push
# !git add .
# !git commit -m "Initial commit from Google Drive"
# !git branch -M main
# !git push -u origin main
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM'
# /content
# Reinitialized existing Git repository in /content/.git/
# error: remote origin already exists.
# error: open("drive/MyDrive/Copy of Resume.gdoc"): Operation not supported
# error: unable to index file 'drive/MyDrive/Copy of Resume.gdoc'
# fatal: adding files failed
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@af855f34b3e4.(none)')
# error: src refspec main does not match any
# ...
