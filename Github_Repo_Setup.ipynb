# %%
from google.colab import drive
drive.mount('/content/drive')

base_dir = "/content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM"
# %cd "$base_dir"


# Init repo
# !git init

# Set identity
# !git config --global user.email "heimowitzdavid@gmail.com"
# !git config --global user.name "David Heimowitz"

# Ignore Google Drive pointer files
# !echo "*.gdoc" >> .gitignore
# !echo "*.gsheet" >> .gitignore
# !echo "*.gslides" >> .gitignore

# Add remote
# !git remote add origin https://github.com/Eyiteus/HRM_Reconstruction.git

# Commit + push
# !git add .
# !git commit -m "Initial commit from Google Drive"
# !git branch -M main
# !git push -u origin main
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM
# Reinitialized existing Git repository in /content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM/.git/
# error: remote origin already exists.
# [main (root-commit) 8003763] Initial commit from Google Drive
#  3 files changed, 5 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 Github_Repo_Setup.ipynb
#  create mode 100644 HRM.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address
