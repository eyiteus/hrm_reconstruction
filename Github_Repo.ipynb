# %%
#Comment this out and add your filepath
# %cd "/content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM"

# !git pull origin main
# Out:
# /content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM
# From https://github.com/Eyiteus/HRM_Reconstruction
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
message =
"""
Separated Sudoku Into Folder

-Changed accuracy to only count predicted tokens
-Changed loss to force identity prediction on given tokens
"""

# !git add .
# !git commit -m """Separated Sudoku Into Folders\n\nChanged accuracy to only count"
# !git push origin main
# Out:
# [main 2538f24] Separated HRM Model Into Folders
#  8 files changed, 119 insertions(+), 2 deletions(-)
#  rewrite HRM.ipynb (89%)
#  create mode 100644 Model/HRM_Components.py
#  create mode 100644 Model/HRM_Model.py
#  create mode 100644 Model/__init__.py
#  create mode 100644 Model/__pycache__/HRM_Components.cpython-312.pyc
#  create mode 100644 Model/__pycache__/HRM_Model.cpython-312.pyc
#  create mode 100644 Model/__pycache__/__init__.cpython-312.pyc
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 10.38 KiB | 231.00 KiB/s, done.
# Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Eyiteus/HRM_Reconstruction.git
#    ffa7903..2538f24  main -> main
