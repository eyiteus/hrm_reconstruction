# %%
#Comment this out and add your filepath
# %cd "/content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM"

# !git pull origin main
# Out:
# /content/drive/MyDrive/Junior/Second Semester/CS 4782 - DL/Final Project - HRM
# From https://github.com/Eyiteus/HRM_Reconstruction
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git add .
# !git commit -m "Separated HRM Model into folde" || echo "No changes to commit"
# !git push origin main
# Out:
# [main ffa7903] Testing Commit Through Colab
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  create mode 100644 Github_Repo.ipynb
#  delete mode 100644 Github_Repo_Setup.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 901 bytes | 90.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Eyiteus/HRM_Reconstruction.git
#    8d57e8b..ffa7903  main -> main
